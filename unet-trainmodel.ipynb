# %%
import os

print(os.listdir('/kaggle/input/datasets/anhpnht/lgg-mri-segmentation'))
# Out:
# ['kaggle_3m', 'lgg-mri-segmentation']

# %%
# !rm -rf Unet_Transformer
# !git clone https://github.com/Anchinlu/Unet_Transformer.git
# %cd Unet_Transformer
# !python train.py --model unet
# Out:
# Cloning into 'Unet_Transformer'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 36 (delta 12), reused 33 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 49.53 KiB | 4.13 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /kaggle/working/Unet_Transformer/Unet_Transformer/Unet_Transformer/Unet_Transformer
# Device: cuda
# Epoch 1/150 - Batch 1/197 - Loss: 1.6309
# Epoch 1/150 - Batch 2/197 - Loss: 1.6149
# Epoch 1/150 - Batch 3/197 - Loss: 1.6304
# Epoch 1/150 - Batch 4/197 - Loss: 1.5609
# Epoch 1/150 - Batch 5/197 - Loss: 1.5946
# Epoch 1/150 - Batch 6/197 - Loss: 1.5240
# Epoch 1/150 - Batch 7/197 - Loss: 1.5533
# Epoch 1/150 - Batch 8/197 - Loss: 1.5275
# Epoch 1/150 - Batch 9/197 - Loss: 1.5043
# Epoch 1/150 - Batch 10/197 - Loss: 1.5379
# Epoch 1/150 - Batch 11/197 - Loss: 1.4845
# Epoch 1/150 - Batch 12/197 - Loss: 1.4890
# ...

# %%
from IPython.display import FileLink
FileLink('unet_best_model.pth')
# Out:
# /kaggle/working/Unet_Transformer/Unet_Transformer/Unet_Transformer/Unet_Transformer/unet_best_model.pth

# %%
# !rm -rf Unet_Transformer
# !git clone https://github.com/Anchinlu/Unet_Transformer.git
# %cd /kaggle/working/Unet_Transformer
# !python train.py --model transunet --batch_size 8
# Out:
# Cloning into 'Unet_Transformer'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 39 (delta 14), reused 35 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 48.94 KiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /kaggle/working/Unet_Transformer
# Device: cuda
# Epoch 1/150 - Batch 1/393 - Loss: 1.6183
# Epoch 1/150 - Batch 2/393 - Loss: 1.6170
# Epoch 1/150 - Batch 3/393 - Loss: 1.5506
# Epoch 1/150 - Batch 4/393 - Loss: 1.5313
# Epoch 1/150 - Batch 5/393 - Loss: 1.5055
# Epoch 1/150 - Batch 6/393 - Loss: 1.5433
# Epoch 1/150 - Batch 7/393 - Loss: 1.5770
# Epoch 1/150 - Batch 8/393 - Loss: 1.5669
# Epoch 1/150 - Batch 9/393 - Loss: 1.4670
# Epoch 1/150 - Batch 10/393 - Loss: 1.4818
# Epoch 1/150 - Batch 11/393 - Loss: 1.5310
# Epoch 1/150 - Batch 12/393 - Loss: 1.4058
# Epoch 1/150 - Batch 13/393 - Loss: 1.5174
# ...

# %%
# !rm -rf Unet_Transformer
# !git clone https://github.com/Anchinlu/Unet_Transformer.git
# Out:
# Cloning into 'Unet_Transformer'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 39 (delta 14), reused 35 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 48.94 KiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# %cd /kaggle/working/Unet_Transformer
# !git pull
# !python train.py --model transunet --batch_size 8 --resume "/kaggle/input/datasets/anhpnht/transunet-best-model/transunet_best_model.pth"
# Out:
# /kaggle/working/Unet_Transformer
# Already up to date.
# Device: cuda
# Loading checkpoint: /kaggle/input/datasets/anhpnht/transunet-best-model/transunet_best_model.pth
# Epoch 1/150 - Batch 1/393 - Loss: 0.2859
# Epoch 1/150 - Batch 2/393 - Loss: 0.8280
# Epoch 1/150 - Batch 3/393 - Loss: 0.3429
# Epoch 1/150 - Batch 4/393 - Loss: 0.3307
# Epoch 1/150 - Batch 5/393 - Loss: 0.4328
# Epoch 1/150 - Batch 6/393 - Loss: 0.0931
# Epoch 1/150 - Batch 7/393 - Loss: 0.8115
# Epoch 1/150 - Batch 8/393 - Loss: 0.2229
# Epoch 1/150 - Batch 9/393 - Loss: 0.1694
# Epoch 1/150 - Batch 10/393 - Loss: 0.2324
# Epoch 1/150 - Batch 11/393 - Loss: 0.2670
# Epoch 1/150 - Batch 12/393 - Loss: 0.1262
# Epoch 1/150 - Batch 13/393 - Loss: 0.3451
# Epoch 1/150 - Batch 14/393 - Loss: 0.0915
# Epoch 1/150 - Batch 15/393 - Loss: 0.2811
# Epoch 1/150 - Batch 16/393 - Loss: 0.2702
# Epoch 1/150 - Batch 17/393 - Loss: 0.1237
# Epoch 1/150 - Batch 18/393 - Loss: 0.2121
# Epoch 1/150 - Batch 19/393 - Loss: 0.1649
# ...
